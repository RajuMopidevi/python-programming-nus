# %% [markdown]
# <center>
#   <a href="PP-03-WritingPrograms.ipynb" target="_self">Writing Programs</a> | <a href="./">Content Page</a> | <a href="PP-04-Operators.ipynb">Operators</a>
# </center>

# %% [markdown]
# # <center>WRITING PROGRAMS SOLUTIONS</center>
# <center><b>Copyright &copy 2023 by DR DANNY POO</b><br> e:dannypoo@nus.edu.sg<br> w:drdannypoo.com</center><br>

# %% [markdown]
# ## Question 1
# Write a Python program to calculate the following expression: <b>15-3*4+30/2-50</b><br>
# Print the result
#
# Expected Output :<br>
# <b>-32.0</b>

# %%
# write code here
print(15-3*4+30/2-50)
# Out:
# -32.0

# %% [markdown]
# ## Question 2
# Write a Python program to construct the following pattern. (Hint: use the print command)<br>
# ![image.png](attachment:image.png)
# Expected Output : <br>
# <b>as shown</b>

# %%
# write code here
print("*")
print("**")
print("***")
print("****")
print("*****")
print("****")
print("***")
print("**")
print("*")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ## Question 3
# Write a Python program to calculate the following expression: <b>(15-3)*4+48/(2-50)</b><br>
# Print the result
#
# Expected Output :<br>
# <b>47.375</b>

# %%
# write code here
print((15-3)*4+48/(2-50))
# Out:
# 47.0

# %% [markdown]
# ## Question 4
# Write a Python program to print alphabet pattern 'E'. (Hint: use the print command)<br>
# ![image-2.png](attachment:image-2.png)
# Expected Output : <br>
# <b>as shown</b>

# %%
# write code here
print("*****")
print("*")
print("*")
print("****")
print("*")
print("*")
print("*****")
# Out:
# *****
# *
# *
# ****
# *
# *
# *****

# %% [markdown]
# ## Question 5
#
# Write a Python program to construct the following pattern. (Hint: use the print command)<br>
# ![image-3.png](attachment:image-3.png)
# Expected Output : <br>
# <b>as shown</b>

# %%
# write code here
print("1")
print("22")
print("333")
print("4444")
print("55555")
print("666666")
print("7777777")
print("88888888")
print("999999999")
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999

# %% [markdown]
# ## Question 6
# Write a Python program to create a dictionary of family members and their age:<br>
# <b>"Father":66, "Mother":64, "Tom":30, "Anne":26, "Jim":21, "Ray":18, "Me":15</b><br>
# Print Mother's, Ray's and my age.<br>
# Print the total age value of the family.
#
# Expected Output :<br>
# <b>Mother's age is 64<br>
# Ray's age is 18<br>
# I am 15<br>
# Total age value is 240 years</b>

# %%
# write code here
familyMembers = {"Father":66, "Mother":64, "Tom":30, "Anne":26, "Jim":21, "Ray":18, "Me":15}
print("Mother's age is", familyMembers["Mother"])
print("Ray's age is", familyMembers["Ray"])     
print("I am", familyMembers["Me"])

totalAge = familyMembers["Father"]+familyMembers["Mother"]+familyMembers["Tom"]+\
           familyMembers["Anne"]+familyMembers["Jim"]+familyMembers["Ray"]+familyMembers["Me"]
print("Total age value is", totalAge, "years")
# Out:
# Mother's age is 64
# Ray's age is 18
# I am 15
# Total age value is 240 years

# %% [markdown]
# <center>
#   <a href="PP-03-WritingPrograms.ipynb" target="_self">Writing Programs</a> | <a href="./">Content Page</a> | <a href="PP-04-Operators.ipynb">Operators</a>
# </center>
